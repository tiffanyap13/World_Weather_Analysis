# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bbe5a870eed2cc340c5eda687dc6c377

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,  
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | dingle
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | hofn
# Processing Record 5 of Set 1 | melville
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | myitkyina
# Processing Record 11 of Set 1 | amahai
# Processing Record 12 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 1 | merauke
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | shache
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | komsomolskiy
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | chumikan
# Processing Record 24 of Set 1 | guerrero negro
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | kununurra
# Processing Record 27 of Set 1 | clyde river
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | kahului
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | coihaique
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | emet
# Processing Record 41 of Set 1 | koumac
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | krapina
# Processing Record 44 of Set 1 | garissa
# Processing Record 45 of Set 1 | atar
# Processing Record 46 of Set 1 | fort nelson
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | sao joao da barra
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | yerbogachen
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | puerto ayacucho
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | kawalu
# Processing Record 8 of Set 2 | taree
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | la primavera
# Processing Record 11 of Set 2 | hovd
# Processing Record 12 of Set 2 | turukhansk
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | diego de almagro
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | coro
# Processing Record 19 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | bathsheba
# Processing Record 22 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 23 of Set 2 | solnechnyy
# Processing Record 24 of Set 2 | srednekolymsk
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | yumen
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | treinta y tres
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | huangpu
# Processing Record 35 of Set 2 | port hardy
# Processing Record 36 of Set 2 | yeppoon
# Processing Record 37 of Set 2 | senanga
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | saint-pierre
# Processing Record 41 of Set 2 | santa maria da boa vista
# Processing Record 42 of Set 2 | road town
# Processing Record 43 of Set 2 | kokstad
# Processing Record 44 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 2 | tilichiki
# Processing Record 46 of Set 2 | xuddur
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | pisco
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | lorengau
# Processing Record 4 of Set 3 | itarema
# Processing Record 5 of Set 3 | acari
# Processing Record 6 of Set 3 | buala
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | sohag
# Processing Record 10 of Set 3 | taoudenni
# Processing Record 11 of Set 3 | newport
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | coxim
# Processing Record 14 of Set 3 | porto novo
# Processing Record 15 of Set 3 | arieseni
# Processing Record 16 of Set 3 | nizhneangarsk
# Processing Record 17 of Set 3 | kilindoni
# Processing Record 18 of Set 3 | fremont
# Processing Record 19 of Set 3 | bintulu
# Processing Record 20 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 21 of Set 3 | colares
# Processing Record 22 of Set 3 | anadyr
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | haines junction
# Processing Record 25 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 3 | asfi
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | yazman
# Processing Record 29 of Set 3 | shimoda
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | policoro
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | madang
# Processing Record 35 of Set 3 | santa ana
# Processing Record 36 of Set 3 | qaanaaq
# Processing Record 37 of Set 3 | maniitsoq
# Processing Record 38 of Set 3 | alexandria
# Processing Record 39 of Set 3 | vilyuysk
# Processing Record 40 of Set 3 | yar-sale
# Processing Record 41 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | palkonda
# Processing Record 43 of Set 3 | hanzhong
# Processing Record 44 of Set 3 | taicheng
# Processing Record 45 of Set 3 | katsuura
# Processing Record 46 of Set 3 | berlevag
# Processing Record 47 of Set 3 | najran
# Processing Record 48 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 3 | cardoso
# Processing Record 50 of Set 3 | barguzin
# Processing Record 1 of Set 4 | adrar
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | balabac
# Processing Record 5 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 4 | bardiyah
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | waipawa
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | terney
# Processing Record 12 of Set 4 | harper
# Processing Record 13 of Set 4 | vanimo
# Processing Record 14 of Set 4 | lagoa
# Processing Record 15 of Set 4 | ferme-neuve
# Processing Record 16 of Set 4 | narsaq
# Processing Record 17 of Set 4 | atka
# City not found. Skipping...
# Processing Record 18 of Set 4 | beni
# Processing Record 19 of Set 4 | coracora
# Processing Record 20 of Set 4 | ambon
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | sorong
# Processing Record 23 of Set 4 | chipinge
# Processing Record 24 of Set 4 | zherdevka
# Processing Record 25 of Set 4 | zhangjiakou
# Processing Record 26 of Set 4 | saskylakh
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | jega
# Processing Record 29 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 4 | avera
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | mahebourg
# Processing Record 33 of Set 4 | dezful
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | baturaja
# Processing Record 36 of Set 4 | sioux lookout
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | iturama
# Processing Record 40 of Set 4 | kuznechikha
# Processing Record 41 of Set 4 | baloda
# Processing Record 42 of Set 4 | dickinson
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | palmer
# Processing Record 45 of Set 4 | college
# Processing Record 46 of Set 4 | new norfolk
# Processing Record 47 of Set 4 | lucea
# Processing Record 48 of Set 4 | weihe
# Processing Record 49 of Set 4 | waterloo
# Processing Record 50 of Set 4 | meulaboh
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | bubaque
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | homer
# Processing Record 5 of Set 5 | mehamn
# Processing Record 6 of Set 5 | emerald
# Processing Record 7 of Set 5 | taksimo
# Processing Record 8 of Set 5 | binzhou
# Processing Record 9 of Set 5 | ayan
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | suluq
# Processing Record 12 of Set 5 | fortuna
# Processing Record 13 of Set 5 | luganville
# Processing Record 14 of Set 5 | burica
# City not found. Skipping...
# Processing Record 15 of Set 5 | caucaia
# Processing Record 16 of Set 5 | flinders
# Processing Record 17 of Set 5 | sur
# Processing Record 18 of Set 5 | nyrob
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | cedar city
# Processing Record 21 of Set 5 | kavant
# City not found. Skipping...
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | dunmore
# Processing Record 24 of Set 5 | saint-leu
# Processing Record 25 of Set 5 | volchansk
# Processing Record 26 of Set 5 | svetlogorsk
# Processing Record 27 of Set 5 | acapulco
# Processing Record 28 of Set 5 | yurga
# Processing Record 29 of Set 5 | rabo de peixe
# Processing Record 30 of Set 5 | asau
# Processing Record 31 of Set 5 | vila velha
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 37 of Set 5 | yining
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | boralday
# Processing Record 40 of Set 5 | chernyakhovsk
# Processing Record 41 of Set 5 | flin flon
# Processing Record 42 of Set 5 | sucua
# Processing Record 43 of Set 5 | yazoo city
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | iralaya
# Processing Record 46 of Set 5 | lulea
# Processing Record 47 of Set 5 | kenai
# Processing Record 48 of Set 5 | shirvan
# Processing Record 49 of Set 5 | vardo
# Processing Record 50 of Set 5 | tarusa
# Processing Record 1 of Set 6 | kafanchan
# Processing Record 2 of Set 6 | thunder bay
# Processing Record 3 of Set 6 | antananarivo
# Processing Record 4 of Set 6 | ostrovnoy
# Processing Record 5 of Set 6 | carbondale
# Processing Record 6 of Set 6 | yenagoa
# Processing Record 7 of Set 6 | karakose
# City not found. Skipping...
# Processing Record 8 of Set 6 | husavik
# Processing Record 9 of Set 6 | lima
# Processing Record 10 of Set 6 | pirovskoye
# Processing Record 11 of Set 6 | maragogi
# Processing Record 12 of Set 6 | river falls
# Processing Record 13 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 14 of Set 6 | noumea
# Processing Record 15 of Set 6 | la rioja
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | stephenville
# Processing Record 18 of Set 6 | lodhran
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 6 | gamboula
# Processing Record 22 of Set 6 | oriximina
# Processing Record 23 of Set 6 | mar del plata
# Processing Record 24 of Set 6 | tapiramuta
# Processing Record 25 of Set 6 | khilok
# Processing Record 26 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 6 | kobyzhcha
# Processing Record 28 of Set 6 | makrana
# Processing Record 29 of Set 6 | alta floresta
# Processing Record 30 of Set 6 | yazykovo
# Processing Record 31 of Set 6 | ardakan
# Processing Record 32 of Set 6 | baruun-urt
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | kosino
# Processing Record 36 of Set 6 | bambous virieux
# Processing Record 37 of Set 6 | barrow
# Processing Record 38 of Set 6 | sangar
# Processing Record 39 of Set 6 | san angelo
# Processing Record 40 of Set 6 | kalevala
# Processing Record 41 of Set 6 | laylay
# Processing Record 42 of Set 6 | shangqiu
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | richards bay
# Processing Record 45 of Set 6 | klaksvik
# Processing Record 46 of Set 6 | opuwo
# Processing Record 47 of Set 6 | ahuimanu
# Processing Record 48 of Set 6 | ekhabi
# Processing Record 49 of Set 6 | namibe
# Processing Record 50 of Set 6 | bria
# Processing Record 1 of Set 7 | kirakira
# Processing Record 2 of Set 7 | kristiansund
# Processing Record 3 of Set 7 | lompoc
# Processing Record 4 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 7 | caravelas
# Processing Record 6 of Set 7 | nioro
# Processing Record 7 of Set 7 | bangkal
# Processing Record 8 of Set 7 | belmonte
# Processing Record 9 of Set 7 | veraval
# Processing Record 10 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 7 | tuatapere
# Processing Record 12 of Set 7 | sambava
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | naze
# Processing Record 15 of Set 7 | norman wells
# Processing Record 16 of Set 7 | rio cuarto
# Processing Record 17 of Set 7 | cotonou
# Processing Record 18 of Set 7 | faanui
# Processing Record 19 of Set 7 | grand-santi
# Processing Record 20 of Set 7 | seymchan
# Processing Record 21 of Set 7 | mlimba
# Processing Record 22 of Set 7 | aleppo
# Processing Record 23 of Set 7 | sena madureira
# Processing Record 24 of Set 7 | blagoyevo
# Processing Record 25 of Set 7 | miranda
# Processing Record 26 of Set 7 | lano
# Processing Record 27 of Set 7 | chapada dos guimaraes
# Processing Record 28 of Set 7 | awjilah
# Processing Record 29 of Set 7 | bonthe
# Processing Record 30 of Set 7 | upington
# Processing Record 31 of Set 7 | yian
# City not found. Skipping...
# Processing Record 32 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 7 | tateyama
# Processing Record 34 of Set 7 | tupancireta
# Processing Record 35 of Set 7 | budogoshch
# Processing Record 36 of Set 7 | mtambile
# Processing Record 37 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 7 | mandera
# Processing Record 39 of Set 7 | varenikovskaya
# Processing Record 40 of Set 7 | pozo colorado
# Processing Record 41 of Set 7 | pevek
# Processing Record 42 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 7 | fairmont
# Processing Record 44 of Set 7 | awbari
# Processing Record 45 of Set 7 | pimentel
# Processing Record 46 of Set 7 | oistins
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | pochutla
# Processing Record 49 of Set 7 | ngunguru
# Processing Record 50 of Set 7 | sawakin
# Processing Record 1 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 8 | xinyang
# Processing Record 3 of Set 8 | holme
# Processing Record 4 of Set 8 | hobbs
# Processing Record 5 of Set 8 | tuktoyaktuk
# Processing Record 6 of Set 8 | mount gambier
# Processing Record 7 of Set 8 | halifax
# Processing Record 8 of Set 8 | evensk
# Processing Record 9 of Set 8 | changji
# Processing Record 10 of Set 8 | cap malheureux
# Processing Record 11 of Set 8 | mount isa
# Processing Record 12 of Set 8 | poum
# Processing Record 13 of Set 8 | krasyliv
# Processing Record 14 of Set 8 | sola
# Processing Record 15 of Set 8 | gizo
# Processing Record 16 of Set 8 | la asuncion
# Processing Record 17 of Set 8 | coquimbo
# Processing Record 18 of Set 8 | zhigansk
# Processing Record 19 of Set 8 | fairbanks
# Processing Record 20 of Set 8 | cabedelo
# Processing Record 21 of Set 8 | lavrentiya
# Processing Record 22 of Set 8 | grenaa
# Processing Record 23 of Set 8 | povenets
# Processing Record 24 of Set 8 | nereju
# Processing Record 25 of Set 8 | seoul
# Processing Record 26 of Set 8 | soe
# Processing Record 27 of Set 8 | marawi
# Processing Record 28 of Set 8 | saryozek
# Processing Record 29 of Set 8 | san vicente
# Processing Record 30 of Set 8 | ust-maya
# Processing Record 31 of Set 8 | necochea
# Processing Record 32 of Set 8 | slevik
# City not found. Skipping...
# Processing Record 33 of Set 8 | moron
# Processing Record 34 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 8 | tiksi
# Processing Record 36 of Set 8 | muncar
# Processing Record 37 of Set 8 | collie
# Processing Record 38 of Set 8 | pathein
# Processing Record 39 of Set 8 | junction city
# Processing Record 40 of Set 8 | northam
# Processing Record 41 of Set 8 | laela
# Processing Record 42 of Set 8 | abu samrah
# Processing Record 43 of Set 8 | rawson
# Processing Record 44 of Set 8 | manadhoo
# Processing Record 45 of Set 8 | sao jose da coroa grande
# Processing Record 46 of Set 8 | iraquara
# Processing Record 47 of Set 8 | nha trang
# Processing Record 48 of Set 8 | jalu
# Processing Record 49 of Set 8 | isangel
# Processing Record 50 of Set 8 | seymour
# Processing Record 1 of Set 9 | victor harbor
# Processing Record 2 of Set 9 | buluang
# Processing Record 3 of Set 9 | usinsk
# Processing Record 4 of Set 9 | portland
# Processing Record 5 of Set 9 | cermik
# Processing Record 6 of Set 9 | pag
# Processing Record 7 of Set 9 | port-cartier
# Processing Record 8 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 9 | anuradhapura
# Processing Record 10 of Set 9 | emba
# Processing Record 11 of Set 9 | ancud
# Processing Record 12 of Set 9 | urfa
# City not found. Skipping...
# Processing Record 13 of Set 9 | ketchikan
# Processing Record 14 of Set 9 | kaitangata
# Processing Record 15 of Set 9 | kapit
# Processing Record 16 of Set 9 | tranas
# Processing Record 17 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 9 | stornoway
# Processing Record 19 of Set 9 | alofi
# Processing Record 20 of Set 9 | ust-kuyga
# Processing Record 21 of Set 9 | vestmannaeyjar
# Processing Record 22 of Set 9 | san patricio
# Processing Record 23 of Set 9 | staryy nadym
# Processing Record 24 of Set 9 | marsa matruh
# Processing Record 25 of Set 9 | sayla
# Processing Record 26 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 9 | laguna
# Processing Record 28 of Set 9 | quelimane
# Processing Record 29 of Set 9 | tortoli
# Processing Record 30 of Set 9 | bridgewater
# Processing Record 31 of Set 9 | lebork
# Processing Record 32 of Set 9 | ashland
# Processing Record 33 of Set 9 | suntar
# Processing Record 34 of Set 9 | lensk
# Processing Record 35 of Set 9 | dingli
# Processing Record 36 of Set 9 | bafq
# Processing Record 37 of Set 9 | aguimes
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | ardmore
# Processing Record 40 of Set 9 | khandyga
# Processing Record 41 of Set 9 | ucluelet
# Processing Record 42 of Set 9 | huaicheng
# Processing Record 43 of Set 9 | caraballeda
# Processing Record 44 of Set 9 | mareeba
# Processing Record 45 of Set 9 | grindavik
# Processing Record 46 of Set 9 | santa isabel do rio negro
# Processing Record 47 of Set 9 | siare
# City not found. Skipping...
# Processing Record 48 of Set 9 | namatanai
# Processing Record 49 of Set 9 | ahipara
# Processing Record 50 of Set 9 | ilulissat
# Processing Record 1 of Set 10 | guymon
# Processing Record 2 of Set 10 | auburn
# Processing Record 3 of Set 10 | nokha
# Processing Record 4 of Set 10 | skjervoy
# Processing Record 5 of Set 10 | ca mau
# Processing Record 6 of Set 10 | sisimiut
# Processing Record 7 of Set 10 | nyaunglebin
# Processing Record 8 of Set 10 | tari
# Processing Record 9 of Set 10 | balkanabat
# Processing Record 10 of Set 10 | sanguem
# Processing Record 11 of Set 10 | lakeside
# Processing Record 12 of Set 10 | jiaozuo
# Processing Record 13 of Set 10 | broome
# Processing Record 14 of Set 10 | sirpur
# Processing Record 15 of Set 10 | fort saint james
# Processing Record 16 of Set 10 | syracuse
# Processing Record 17 of Set 10 | jucuaran
# Processing Record 18 of Set 10 | catuday
# Processing Record 19 of Set 10 | barra
# Processing Record 20 of Set 10 | mitchell
# Processing Record 21 of Set 10 | potosi
# Processing Record 22 of Set 10 | auki
# Processing Record 23 of Set 10 | kaka
# Processing Record 24 of Set 10 | verkhnevilyuysk
# Processing Record 25 of Set 10 | houma
# Processing Record 26 of Set 10 | riberalta
# Processing Record 27 of Set 10 | chapais
# Processing Record 28 of Set 10 | tura
# Processing Record 29 of Set 10 | talnakh
# Processing Record 30 of Set 10 | eureka
# Processing Record 31 of Set 10 | makurdi
# Processing Record 32 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 10 | kurilsk
# Processing Record 34 of Set 10 | marystown
# Processing Record 35 of Set 10 | gavle
# Processing Record 36 of Set 10 | san juan
# Processing Record 37 of Set 10 | valle de allende
# Processing Record 38 of Set 10 | brigantine
# Processing Record 39 of Set 10 | marsh harbour
# Processing Record 40 of Set 10 | tiarei
# Processing Record 41 of Set 10 | burnie
# Processing Record 42 of Set 10 | omsukchan
# Processing Record 43 of Set 10 | nouadhibou
# Processing Record 44 of Set 10 | bulawayo
# Processing Record 45 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 10 | astorga
# Processing Record 47 of Set 10 | shimanovsk
# Processing Record 48 of Set 10 | sotouboua
# Processing Record 49 of Set 10 | strazica
# City not found. Skipping...
# Processing Record 50 of Set 10 | wodonga
# Processing Record 1 of Set 11 | pangody
# Processing Record 2 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 3 of Set 11 | ritchie
# Processing Record 4 of Set 11 | cam ranh
# Processing Record 5 of Set 11 | brae
# Processing Record 6 of Set 11 | inhambane
# Processing Record 7 of Set 11 | nadadores
# Processing Record 8 of Set 11 | payo
# Processing Record 9 of Set 11 | urcos
# Processing Record 10 of Set 11 | bereda
# Processing Record 11 of Set 11 | turbat
# Processing Record 12 of Set 11 | saint anthony
# Processing Record 13 of Set 11 | general roca
# Processing Record 14 of Set 11 | killybegs
# Processing Record 15 of Set 11 | murray bridge
# Processing Record 16 of Set 11 | pemagatsel
# Processing Record 17 of Set 11 | simao
# Processing Record 18 of Set 11 | newton
# Processing Record 19 of Set 11 | smolenka
# Processing Record 20 of Set 11 | salto
# Processing Record 21 of Set 11 | tazovskiy
# Processing Record 22 of Set 11 | kuminskiy
# Processing Record 23 of Set 11 | chicama
# Processing Record 24 of Set 11 | caloundra
# Processing Record 25 of Set 11 | karpathos
# Processing Record 26 of Set 11 | rudkobing
# Processing Record 27 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 28 of Set 11 | hidalgotitlan
# Processing Record 29 of Set 11 | mugur-aksy
# Processing Record 30 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 31 of Set 11 | boguchany
# Processing Record 32 of Set 11 | hammerfest
# Processing Record 33 of Set 11 | praia da vitoria
# Processing Record 34 of Set 11 | guhagar
# Processing Record 35 of Set 11 | sechura
# Processing Record 36 of Set 11 | aldama
# Processing Record 37 of Set 11 | chernyshevskiy
# Processing Record 38 of Set 11 | oranjemund
# Processing Record 39 of Set 11 | sergeyevka
# Processing Record 40 of Set 11 | gigmoto
# Processing Record 41 of Set 11 | verkhnyaya khava
# Processing Record 42 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 11 | beloha
# Processing Record 45 of Set 11 | pochinki
# Processing Record 46 of Set 11 | kloulklubed
# Processing Record 47 of Set 11 | port hedland
# Processing Record 48 of Set 11 | honningsvag
# Processing Record 49 of Set 11 | gudari
# Processing Record 50 of Set 11 | vostok
# Processing Record 1 of Set 12 | lerwick
# Processing Record 2 of Set 12 | machilipatnam
# Processing Record 3 of Set 12 | itoman
# Processing Record 4 of Set 12 | sainte-suzanne
# Processing Record 5 of Set 12 | oum hadjer
# Processing Record 6 of Set 12 | honiara
# Processing Record 7 of Set 12 | nampa
# Processing Record 8 of Set 12 | edd
# Processing Record 9 of Set 12 | san andres
# Processing Record 10 of Set 12 | deputatskiy
# Processing Record 11 of Set 12 | mayo
# Processing Record 12 of Set 12 | cuamba
# Processing Record 13 of Set 12 | bilma
# Processing Record 14 of Set 12 | sept-iles
# Processing Record 15 of Set 12 | puerto escondido
# Processing Record 16 of Set 12 | natalio
# Processing Record 17 of Set 12 | ordynskoye
# Processing Record 18 of Set 12 | cockburn town
# Processing Record 19 of Set 12 | paita
# Processing Record 20 of Set 12 | paralia
# Processing Record 21 of Set 12 | kwekwe
# Processing Record 22 of Set 12 | la ronge
# Processing Record 23 of Set 12 | mantua
# Processing Record 24 of Set 12 | bogorodskoye
# Processing Record 25 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 12 | fort abbas
# Processing Record 27 of Set 12 | okhotsk
# Processing Record 28 of Set 12 | mastic beach
# Processing Record 29 of Set 12 | marshall
# Processing Record 30 of Set 12 | japura
# Processing Record 31 of Set 12 | vorozhba
# Processing Record 32 of Set 12 | oron
# Processing Record 33 of Set 12 | kenora
# Processing Record 34 of Set 12 | vila
# Processing Record 35 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 12 | tabou
# Processing Record 37 of Set 12 | beringovskiy
# Processing Record 38 of Set 12 | paamiut
# Processing Record 39 of Set 12 | verdalsora
# City not found. Skipping...
# Processing Record 40 of Set 12 | pariquera-acu
# City not found. Skipping...
# Processing Record 41 of Set 12 | ribeira brava
# Processing Record 42 of Set 12 | kardla
# Processing Record 43 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 12 | ialibu
# Processing Record 45 of Set 12 | wad madani
# Processing Record 46 of Set 12 | angoche
# Processing Record 47 of Set 12 | aitape
# Processing Record 48 of Set 12 | taltal
# Processing Record 49 of Set 12 | kuusamo
# Processing Record 50 of Set 12 | sagar
# Processing Record 1 of Set 13 | doctor arroyo
# Processing Record 2 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 13 | promyshlennaya
# Processing Record 4 of Set 13 | suixi
# Processing Record 5 of Set 13 | mbale
# Processing Record 6 of Set 13 | jeronimo monteiro
# Processing Record 7 of Set 13 | port-gentil
# Processing Record 8 of Set 13 | winslow
# Processing Record 9 of Set 13 | labuhan
# Processing Record 10 of Set 13 | amalapuram
# Processing Record 11 of Set 13 | bonavista
# Processing Record 12 of Set 13 | nador
# Processing Record 13 of Set 13 | olafsvik
# Processing Record 14 of Set 13 | monrovia
# Processing Record 15 of Set 13 | dakoro
# Processing Record 16 of Set 13 | krasnoselkup
# Processing Record 17 of Set 13 | la romana
# Processing Record 18 of Set 13 | carutapera
# Processing Record 19 of Set 13 | santa maria
# Processing Record 20 of Set 13 | edgewater
# Processing Record 21 of Set 13 | corumba
# Processing Record 22 of Set 13 | muisne
# Processing Record 23 of Set 13 | gap
# Processing Record 24 of Set 13 | margate
# Processing Record 25 of Set 13 | galle
# Processing Record 26 of Set 13 | dangriga
# Processing Record 27 of Set 13 | markova
# Processing Record 28 of Set 13 | stromness
# Processing Record 29 of Set 13 | manuk mangkaw
# Processing Record 30 of Set 13 | katsina
# Processing Record 31 of Set 13 | west bay
# Processing Record 32 of Set 13 | comodoro rivadavia
# Processing Record 33 of Set 13 | agadez
# Processing Record 34 of Set 13 | upata
# Processing Record 35 of Set 13 | itaueira
# Processing Record 36 of Set 13 | mandiana
# Processing Record 37 of Set 13 | kita
# Processing Record 38 of Set 13 | requena
# Processing Record 39 of Set 13 | tatarusi
# Processing Record 40 of Set 13 | westport
# Processing Record 41 of Set 13 | makakilo city
# Processing Record 42 of Set 13 | thinadhoo
# Processing Record 43 of Set 13 | dourbali
# Processing Record 44 of Set 13 | piacabucu
# Processing Record 45 of Set 13 | tautira
# Processing Record 46 of Set 13 | tarko-sale
# Processing Record 47 of Set 13 | tecoanapa
# Processing Record 48 of Set 13 | russell
# Processing Record 49 of Set 13 | padang
# Processing Record 50 of Set 13 | umm lajj
# Processing Record 1 of Set 14 | batagay-alyta
# Processing Record 2 of Set 14 | qasigiannguit
# Processing Record 3 of Set 14 | kyrylivka
# Processing Record 4 of Set 14 | istok
# Processing Record 5 of Set 14 | tomatlan
# Processing Record 6 of Set 14 | eyl
# Processing Record 7 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 14 | te anau
# Processing Record 9 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 14 | sobolevo
# Processing Record 11 of Set 14 | ozuluama
# Processing Record 12 of Set 14 | domoni
# Processing Record 13 of Set 14 | kurchum
# Processing Record 14 of Set 14 | zyryanka
# Processing Record 15 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 14 | kieta
# Processing Record 17 of Set 14 | hami
# Processing Record 18 of Set 14 | humaita
# Processing Record 19 of Set 14 | tres arroyos
# Processing Record 20 of Set 14 | enid
# Processing Record 21 of Set 14 | tottori
# Processing Record 22 of Set 14 | cherskiy
# Processing Record 23 of Set 14 | maymanak
# City not found. Skipping...
# Processing Record 24 of Set 14 | jever
# Processing Record 25 of Set 14 | matay
# Processing Record 26 of Set 14 | buin
# Processing Record 27 of Set 14 | garowe
# Processing Record 28 of Set 14 | boddam
# Processing Record 29 of Set 14 | beisfjord
# Processing Record 30 of Set 14 | kachug
# Processing Record 31 of Set 14 | skelleftea
# Processing Record 32 of Set 14 | tabas
# Processing Record 33 of Set 14 | graaff-reinet
# Processing Record 34 of Set 14 | anito
# Processing Record 35 of Set 14 | luena
# Processing Record 36 of Set 14 | liverpool
# Processing Record 37 of Set 14 | burns lake
# Processing Record 38 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 39 of Set 14 | progreso
# Processing Record 40 of Set 14 | ola
# Processing Record 41 of Set 14 | rundu
# Processing Record 42 of Set 14 | puranpur
# Processing Record 43 of Set 14 | doha
# Processing Record 44 of Set 14 | aranos
# Processing Record 45 of Set 14 | mogadishu
# Processing Record 46 of Set 14 | broken hill
# Processing Record 47 of Set 14 | ipora
# Processing Record 48 of Set 14 | henzada
# City not found. Skipping...
# Processing Record 49 of Set 14 | nichinan
# Processing Record 50 of Set 14 | kyra
# Processing Record 1 of Set 15 | zatoka
# Processing Record 2 of Set 15 | quatre cocos
# Processing Record 3 of Set 15 | darova
# Processing Record 4 of Set 15 | dubbo
# Processing Record 5 of Set 15 | mutoko
# Processing Record 6 of Set 15 | kunming
# Processing Record 7 of Set 15 | kazachinskoye
# Processing Record 8 of Set 15 | puerto suarez
# Processing Record 9 of Set 15 | talca
# Processing Record 10 of Set 15 | uyuni
# Processing Record 11 of Set 15 | carauari
# Processing Record 12 of Set 15 | palu
# Processing Record 13 of Set 15 | konstantinovka
# Processing Record 14 of Set 15 | fare
# Processing Record 15 of Set 15 | arlit
# Processing Record 16 of Set 15 | pandharpur
# Processing Record 17 of Set 15 | araripe
# Processing Record 18 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 15 | souillac
# Processing Record 20 of Set 15 | nagorsk
# Processing Record 21 of Set 15 | yeniseysk
# Processing Record 22 of Set 15 | nefteyugansk
# Processing Record 23 of Set 15 | agva
# City not found. Skipping...
# Processing Record 24 of Set 15 | mbala
# Processing Record 25 of Set 15 | prokopyevsk
# Processing Record 26 of Set 15 | khatassy
# Processing Record 27 of Set 15 | pedernales
# Processing Record 28 of Set 15 | dauriya
# Processing Record 29 of Set 15 | farafangana
# Processing Record 30 of Set 15 | rantauprapat
# Processing Record 31 of Set 15 | san-pedro
# Processing Record 32 of Set 15 | doctor juan manuel frutos
# Processing Record 33 of Set 15 | ambovombe
# Processing Record 34 of Set 15 | neubrandenburg
# Processing Record 35 of Set 15 | nouakchott
# Processing Record 36 of Set 15 | boras
# Processing Record 37 of Set 15 | patiya
# Processing Record 38 of Set 15 | kiruna
# Processing Record 39 of Set 15 | port lincoln
# Processing Record 40 of Set 15 | kaeo
# Processing Record 41 of Set 15 | porto walter
# Processing Record 42 of Set 15 | rapar
# Processing Record 43 of Set 15 | atbasar
# Processing Record 44 of Set 15 | tamandare
# Processing Record 45 of Set 15 | banda aceh
# Processing Record 46 of Set 15 | shubarkuduk
# Processing Record 47 of Set 15 | lac du bonnet
# Processing Record 48 of Set 15 | urdoma
# Processing Record 49 of Set 15 | san benito abad
# Processing Record 50 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 16 | kokopo
# Processing Record 2 of Set 16 | peleduy
# Processing Record 3 of Set 16 | bosaso
# Processing Record 4 of Set 16 | sakaraha
# Processing Record 5 of Set 16 | mecca
# -----------------------------
# Data Retrieval Complete

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Mataura -46.1927  168.8643     61.00        78         100       10.00
# 1       Dingle  10.9995  122.6711     80.74        71           6       14.47
# 2    Busselton -33.6500  115.3333     79.00        57         100        3.00
# 3         Hofn  64.2539  -15.2082     38.37        84         100       27.60
# 4     Melville  40.7934  -73.4151     53.60        32           1        6.91
# ..         ...      ...       ...       ...       ...         ...         ...
# 687     Kokopo  -4.3520  152.2633     83.84        66          63        4.52
# 688    Peleduy  59.6289  112.7406     12.69        92         100       14.32
# 689     Bosaso  11.2842   49.1816     74.95        69           0        5.68
# 690   Sakaraha -22.9000   44.5333     67.59        88           0        2.82
# 691      Mecca  21.4267   39.8261     74.91        53           0        2.77
#
#     Country Current Description
# 0        NZ     overcast clouds
# 1        PH           clear sky
# 2        AU     overcast clouds
# 3        IS          light rain
# 4        US           clear sky
# ..      ...                 ...
# 687      PG       broken clouds
# 688      RU     overcast clouds
# 689      SO           clear sky
# 690      MG           clear sky
# 691      SA           clear sky
#
# [692 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mataura      NZ -46.1927  168.8643     61.00        78         100
# 1       Dingle      PH  10.9995  122.6711     80.74        71           6
# 2    Busselton      AU -33.6500  115.3333     79.00        57         100
# 3         Hofn      IS  64.2539  -15.2082     38.37        84         100
# 4     Melville      US  40.7934  -73.4151     53.60        32           1
# ..         ...     ...      ...       ...       ...       ...         ...
# 687     Kokopo      PG  -4.3520  152.2633     83.84        66          63
# 688    Peleduy      RU  59.6289  112.7406     12.69        92         100
# 689     Bosaso      SO  11.2842   49.1816     74.95        69           0
# 690   Sakaraha      MG -22.9000   44.5333     67.59        88           0
# 691      Mecca      SA  21.4267   39.8261     74.91        53           0
#
#      Wind Speed Current Description
# 0         10.00     overcast clouds
# 1         14.47           clear sky
# 2          3.00     overcast clouds
# 3         27.60          light rain
# 4          6.91           clear sky
# ..          ...                 ...
# 687        4.52       broken clouds
# 688       14.32     overcast clouds
# 689        5.68           clear sky
# 690        2.82           clear sky
# 691        2.77           clear sky
#
# [692 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
